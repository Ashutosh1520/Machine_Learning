# %%
# importing necessary packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# putting csv file into pandas dataframe
df = pd.read_csv("/content/tcs_train.csv")

# to read starting 5 rows of dataset
df.head()
# Out:
#   internship_id  ... evaluation_status
# 0          p137  ...          SELECTED
# 1          p151  ...          SELECTED
# 2          p186  ...          SELECTED
# 3          p186  ...          SELECTED
# 4          p138  ...          REJECTED
#
# [5 rows x 5 columns]

# %%
# removing evaluation_status from dataframe df1
df1=df.drop(['evaluation_status'], axis = 1)

# %%
df1
# Out:
#     internship_id  ...                                             skills
# 0            p137  ...  Digital Circuits,Python,Java,C programming,MIC...
# 1            p151  ...                           C programming,Python,C++
# 2            p186  ...  Cloud Computing   AWS,networking,Digital Circu...
# 3            p186  ...  Animation and Game Development,Application des...
# 4            p138  ...                                C,Java,mysql,Python
# ..            ...  ...                                                ...
# 943          p638  ...  C,Python,Machine learning,Java,HTML,css,sql,js...
# 944          p667  ...  C,Python,Machine learning,Java,HTML,css,sql,js...
# 945          p713  ...  C,Python,Machine learning,Java,HTML,css,sql,js...
# 946          p700  ...  Algorithms and Data Structures,Android App Dev...
# 947          p646  ...  Android development,Web Development,Programmin...
#
# [948 rows x 4 columns]

# %%
# combining columns into one column
df1["text"] = df1["skills"].astype(str)+" "+df1["location"].astype(str)+" "+df1["login"].astype(str)

# %%
df1
# Out:
#     internship_id  ...                                               text
# 0            p137  ...  Digital Circuits,Python,Java,C programming,MIC...
# 1            p151  ...                C programming,Python,C++ Chennai c4
# 2            p186  ...  Cloud Computing   AWS,networking,Digital Circu...
# 3            p186  ...  Animation and Game Development,Application des...
# 4            p138  ...                   C,Java,mysql,Python Hyderabad c8
# ..            ...  ...                                                ...
# 943          p638  ...  C,Python,Machine learning,Java,HTML,css,sql,js...
# 944          p667  ...  C,Python,Machine learning,Java,HTML,css,sql,js...
# 945          p713  ...  C,Python,Machine learning,Java,HTML,css,sql,js...
# 946          p700  ...  Algorithms and Data Structures,Android App Dev...
# 947          p646  ...  Android development,Web Development,Programmin...
#
# [948 rows x 5 columns]

# %%
# removing location, skills and internship from dataframe df1
df1.drop(['location', 'skills','internship_id'], axis = 1, inplace= True)

# %%
df1
# Out:
#     login                                               text
# 0      c2  Digital Circuits,Python,Java,C programming,MIC...
# 1      c4                C programming,Python,C++ Chennai c4
# 2      c5  Cloud Computing   AWS,networking,Digital Circu...
# 3      c6  Animation and Game Development,Application des...
# 4      c8                   C,Java,mysql,Python Hyderabad c8
# ..    ...                                                ...
# 943  c814  C,Python,Machine learning,Java,HTML,css,sql,js...
# 944  c814  C,Python,Machine learning,Java,HTML,css,sql,js...
# 945  c814  C,Python,Machine learning,Java,HTML,css,sql,js...
# 946  c815  Algorithms and Data Structures,Android App Dev...
# 947  c817  Android development,Web Development,Programmin...
#
# [948 rows x 2 columns]

# %%
# putting csv file into pandas dataframe
df5 = pd.read_csv("/content/tcs_test.csv")

# to read starting 5 rows of dataset
df5.head()
# Out:
#   candidate_id location                                             skills
# 0           c1  Kolkata          C,C++,Java,Android Studio,msoffice,Python
# 1           c3  Chennai                    networking,C programming,Python
# 2           c7  Chennai  Unity 3D,AR,C sharp,C,JAVA PROGRAMMING,Servlet...
# 3          c15   Mumbai  Javascript,C++,Java,Python,css,HTML,mongoDB,Re...
# 4          c16  Kolkata  C,Core Java,Python,Data Structures   Algorithm...

# %%
# combining columns into one column
df5["text"] = df5["skills"].astype(str)+" "+df5["location"].astype(str)+" "+df5["candidate_id"].astype(str)

# %%
df5.head()
# Out:
#   candidate_id  ...                                               text
# 0           c1  ...  C,C++,Java,Android Studio,msoffice,Python Kolk...
# 1           c3  ...         networking,C programming,Python Chennai c3
# 2           c7  ...  Unity 3D,AR,C sharp,C,JAVA PROGRAMMING,Servlet...
# 3          c15  ...  Javascript,C++,Java,Python,css,HTML,mongoDB,Re...
# 4          c16  ...  C,Core Java,Python,Data Structures   Algorithm...
#
# [5 rows x 4 columns]

# %%
# removing location and skills from dataframe df5
df5.drop(['location', 'skills'], axis = 1, inplace= True)

# %%
df5
# Out:
#     candidate_id                                               text
# 0             c1  C,C++,Java,Android Studio,msoffice,Python Kolk...
# 1             c3         networking,C programming,Python Chennai c3
# 2             c7  Unity 3D,AR,C sharp,C,JAVA PROGRAMMING,Servlet...
# 3            c15  Javascript,C++,Java,Python,css,HTML,mongoDB,Re...
# 4            c16  C,Core Java,Python,Data Structures   Algorithm...
# ..           ...                                                ...
# 145         c803  C++,Data Analytics using Python,HTML,css Luckn...
# 146         c808  algorithm,Data Structure,backend development,W...
# 147         c811                  Python,Java,C,C++ Trivandrum c811
# 148         c813            Python,Java,Deep Learning,C Mumbai c813
# 149         c816  c language,Java,Python,sql,Machine learning Hy...
#
# [150 rows x 2 columns]

# %%
# renaming column candidate_id as login
df5.rename(columns = {'candidate_id':'login'}, inplace = True)

# %%
df5
# Out:
#     login                                               text
# 0      c1  C,C++,Java,Android Studio,msoffice,Python Kolk...
# 1      c3         networking,C programming,Python Chennai c3
# 2      c7  Unity 3D,AR,C sharp,C,JAVA PROGRAMMING,Servlet...
# 3     c15  Javascript,C++,Java,Python,css,HTML,mongoDB,Re...
# 4     c16  C,Core Java,Python,Data Structures   Algorithm...
# ..    ...                                                ...
# 145  c803  C++,Data Analytics using Python,HTML,css Luckn...
# 146  c808  algorithm,Data Structure,backend development,W...
# 147  c811                  Python,Java,C,C++ Trivandrum c811
# 148  c813            Python,Java,Deep Learning,C Mumbai c813
# 149  c816  c language,Java,Python,sql,Machine learning Hy...
#
# [150 rows x 2 columns]

# %%
# combining dataframe df1 and df5 to df6
df6 = df1.append(df5, ignore_index=True)

# %%
df6
# Out:
#      login                                               text
# 0       c2  Digital Circuits,Python,Java,C programming,MIC...
# 1       c4                C programming,Python,C++ Chennai c4
# 2       c5  Cloud Computing   AWS,networking,Digital Circu...
# 3       c6  Animation and Game Development,Application des...
# 4       c8                   C,Java,mysql,Python Hyderabad c8
# ...    ...                                                ...
# 1093  c803  C++,Data Analytics using Python,HTML,css Luckn...
# 1094  c808  algorithm,Data Structure,backend development,W...
# 1095  c811                  Python,Java,C,C++ Trivandrum c811
# 1096  c813            Python,Java,Deep Learning,C Mumbai c813
# 1097  c816  c language,Java,Python,sql,Machine learning Hy...
#
# [1098 rows x 2 columns]

# %%
# copying dataframe df6 to dataframe df1 
df1=df6

# %%
# printing all rows
c=0
for i in df1.text:
    print(c,i)
    print()
    c=c+1
# Out:
# 0 Digital Circuits,Python,Java,C programming,MICROPROCESSOR AND MICROCONTROLLER Chennai c2
#
# 1 C programming,Python,C++ Chennai c4
#
# 2 Cloud Computing   AWS,networking,Digital Circuits,Artificial Intelligence   ML  DL,Data Analytics,blockchain Chennai c5
#
# 3 Animation and Game Development,Application designing,Python programming,networking,ELECTRONICS,Core Java Chennai c6
#
# 4 C,Java,mysql,Python Hyderabad c8
#
# 5 python3 Hyderabad c9
#
# 6 python3 Hyderabad c9
#
# 7 c language,Python,HTML,css,Core Java,mysql Hyderabad c10
#
# 8 Java,Python,PHP Hyderabad c11
#
# 9 C programming,Cpp Programming,JAVA PROGRAMMING,Python programming,R Programming,Scala programming Hyderabad c12
#
# 10 C,C++,Python,sql,Django Framework,Tkinter Kolkata c13
#
# 11 C,C++,Python,sql,Django Framework,Tkinter Kolkata c13
#
# 12 C,cpp,Java,Python,Mondo DB,sql,PHP,Bootstrap Hyderabad c14
#
# 13 web design,Python,C++,Java Kolkata c18
#
# ...

# %%
# appending values to list
a=[]
for i in df1.text:
    x=str(i)
    a.append(x)

# %%
s='$'.join(a)

# %%
# creating a text corpus
s
# Out:
# 'Digital Circuits,Python,Java,C programming,MICROPROCESSOR AND MICROCONTROLLER Chennai c2$C programming,Python,C++ Chennai c4$Cloud Computing   AWS,networking,Digital Circuits,Artificial Intelligence   ML  DL,Data Analytics,blockchain Chennai c5$Animation and Game Development,Application designing,Python programming,networking,ELECTRONICS,Core Java Chennai c6$C,Java,mysql,Python Hyderabad c8$python3 Hyderabad c9$python3 Hyderabad c9$c language,Python,HTML,css,Core Java,mysql Hyderabad c10$Java,Python,PHP Hyderabad c11$C programming,Cpp Programming,JAVA PROGRAMMING,Python programming,R Programming,Scala programming Hyderabad c12$C,C++,Python,sql,Django Framework,Tkinter Kolkata c13$C,C++,Python,sql,Django Framework,Tkinter Kolkata c13$C,cpp,Java,Python,Mondo DB,sql,PHP,Bootstrap Hyderabad c14$web design,Python,C++,Java Kolkata c18$Cloud Computing,programming in python,Programming in c,Kubernetes Chennai c19$React Js,node js,Python,Tensorflow,Machine Learning algorithms,mysql,mongo db,
# ...

# %%
# importing tensorflow for creating neural net
import tensorflow as tf

from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Embedding, LSTM, Dense, Bidirectional
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
import numpy as np

# %%
# tokenizing words
tokenizer = Tokenizer()

data = s
# creating python list of lowercase words by using split on $
corpus = data.lower().split("$")
# creating dictionary of words on overall corpus
# key-> word
# value-> token for that word
tokenizer.fit_on_texts(corpus)
total_words = len(tokenizer.word_index) + 1

print(tokenizer.word_index)
# printing total number of words
print(total_words)
# Out:
# {'c': 1, 'python': 2, 'java': 3, 'learning': 4, 'chennai': 5, 'html': 6, 'data': 7, 'machine': 8, 'css': 9, 'programming': 10, 'hyderabad': 11, 'sql': 12, 'javascript': 13, 'development': 14, 'android': 15, 'structures': 16, 'kolkata': 17, 'and': 18, 'algorithms': 19, 'mysql': 20, 'js': 21, 'web': 22, 'delhi': 23, 'php': 24, 'deep': 25, 'dbms': 26, 'language': 27, 'mumbai': 28, 'django': 29, 'nodejs': 30, 'node': 31, 'structure': 32, 'cloud': 33, 'mongodb': 34, 'bangalore': 35, 'react': 36, 'bootstrap': 37, 'aws': 38, 'science': 39, 'processing': 40, 'computer': 41, 'computing': 42, 'r': 43, 'ahmedabad': 44, 'pune': 45, 'blockchain': 46, 'of': 47, 'git': 48, 'oriented': 49, 'cpp': 50, 'matlab': 51, 'linux': 52, 'app': 53, 'arduino': 54, 'competitive': 55, 'object': 56, 'database': 57, 'problem': 58, 'solving': 59, 'core': 60, 'angular': 61, 'iot': 62, 'flask': 63, 'script': 64, 'html5': 65, 'analytics': 66, 'studio': 67, 'adobe': 68, 'algorithm': 69, 'design': 70, 'spring': 71, 'netw
# ...

# %%
input_sequences = []
for line in corpus:
	token_list = tokenizer.texts_to_sequences([line])[0]
	for i in range(1, len(token_list)):
		n_gram_sequence = token_list[:i+1]
		input_sequences.append(n_gram_sequence)

# pad sequences 
max_sequence_len = max([len(x) for x in input_sequences])
input_sequences = np.array(pad_sequences(input_sequences, maxlen=max_sequence_len, padding='pre'))

# create predictors and label
xs, labels = input_sequences[:,:-1],input_sequences[:,-1]

ys = tf.keras.utils.to_categorical(labels, num_classes=total_words)

# %%
print(tokenizer.word_index)
# Out:
# {'c': 1, 'python': 2, 'java': 3, 'learning': 4, 'chennai': 5, 'html': 6, 'data': 7, 'machine': 8, 'css': 9, 'programming': 10, 'hyderabad': 11, 'sql': 12, 'javascript': 13, 'development': 14, 'android': 15, 'structures': 16, 'kolkata': 17, 'and': 18, 'algorithms': 19, 'mysql': 20, 'js': 21, 'web': 22, 'delhi': 23, 'php': 24, 'deep': 25, 'dbms': 26, 'language': 27, 'mumbai': 28, 'django': 29, 'nodejs': 30, 'node': 31, 'structure': 32, 'cloud': 33, 'mongodb': 34, 'bangalore': 35, 'react': 36, 'bootstrap': 37, 'aws': 38, 'science': 39, 'processing': 40, 'computer': 41, 'computing': 42, 'r': 43, 'ahmedabad': 44, 'pune': 45, 'blockchain': 46, 'of': 47, 'git': 48, 'oriented': 49, 'cpp': 50, 'matlab': 51, 'linux': 52, 'app': 53, 'arduino': 54, 'competitive': 55, 'object': 56, 'database': 57, 'problem': 58, 'solving': 59, 'core': 60, 'angular': 61, 'iot': 62, 'flask': 63, 'script': 64, 'html5': 65, 'analytics': 66, 'studio': 67, 'adobe': 68, 'algorithm': 69, 'design': 70, 'spring': 71, 'netw
# ...

# %%
# deleting variables to free up memory
del df
del a
del df1
del s

# %%
# creating neural network
model = Sequential()
model.add(Embedding(total_words, 100, input_length=max_sequence_len-1))
model.add(Bidirectional(LSTM(150)))
model.add(Dense(total_words, activation='softmax'))
adam = Adam(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])
history = model.fit(xs, ys, epochs=100, verbose=1)
print(model)
# Out:
# Epoch 1/100
# 357/357 [==============================] - 13s 11ms/step - loss: 5.1139 - accuracy: 0.1151
# Epoch 2/100
# 357/357 [==============================] - 4s 11ms/step - loss: 3.6482 - accuracy: 0.2673
# Epoch 3/100
# 357/357 [==============================] - 4s 11ms/step - loss: 2.8622 - accuracy: 0.3632
# Epoch 4/100
# 357/357 [==============================] - 4s 11ms/step - loss: 2.3303 - accuracy: 0.4369
# Epoch 5/100
# 357/357 [==============================] - 4s 11ms/step - loss: 1.9074 - accuracy: 0.5173
# Epoch 6/100
# 357/357 [==============================] - 4s 10ms/step - loss: 1.6611 - accuracy: 0.5737
# Epoch 7/100
# 357/357 [==============================] - 4s 10ms/step - loss: 1.4861 - accuracy: 0.6077
# Epoch 8/100
# 357/357 [==============================] - 4s 11ms/step - loss: 1.3239 - accuracy: 0.6459
# Epoch 9/100
# 357/357 [==============================] - 4s 11ms/step - loss: 1.2152 - accuracy: 0.6731
# Epoch 10/100
# ...

# %%
import matplotlib.pyplot as plt


def plot_graphs(history, string):
    plt.plot(history.history[string])
    plt.xlabel("Epochs")
    plt.ylabel(string)
    plt.show()

# %%
# plotting accuracy vs epochs graph
plot_graphs(history, 'accuracy')

# %%
# predicting next word using neural net
seed_text = "Chennai"
next_words = 1
  
for _ in range(next_words):
	token_list = tokenizer.texts_to_sequences([seed_text])[0]
	token_list = pad_sequences([token_list], maxlen=max_sequence_len-1, padding='pre')
	predicted = model.predict_classes(token_list, verbose=0)
	output_word = ""
	for word, index in tokenizer.word_index.items():
		if index == predicted:
			output_word = word
			break
	seed_text += " " + output_word
print(seed_text)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# Chennai ar

# %%
# putting csv file into pandas dataframe
df1 = pd.read_csv("/content/tcs_project.csv")

# to read starting 5 rows of dataset
df1.head()
# Out:
#    id  ...                                        description
# 0  p3  ...  <p>XYZ is in process to Digital Upgrade proces...
# 1  p4  ...  <p>XYZ is in process to Digital Upgrade proces...
# 2  p5  ...  <p>DevOps is the one of the most sought after ...
# 3  p6  ...  <p>This is a core asset being Developed within...
# 4  p7  ...  <p>The financial services and insurance indust...
#
# [5 rows x 5 columns]

# %%
# removing location and skills from dataframe df1
df1.drop(['mode', 'description'], axis = 1, inplace= True)

# %%
df1.head()
# Out:
#    id location          required_skills
# 0  p3  Kolkata  Anroid, iOS Development
# 1  p4  Kolkata       Java,Python,Groovy
# 2  p5  Kolkata       Python,Groovy,Java
# 3  p6  Kolkata       Python,Groovy,Java
# 4  p7  Chennai   UI/UX Designing skills

# %%
df1["text"] = df1["required_skills"].astype(str)+" "+df1["location"].astype(str)

# %%
df1
# Out:
#        id  ...                                               text
# 0      p3  ...                    Anroid, iOS Development Kolkata
# 1      p4  ...                         Java,Python,Groovy Kolkata
# 2      p5  ...                         Python,Groovy,Java Kolkata
# 3      p6  ...                         Python,Groovy,Java Kolkata
# 4      p7  ...                     UI/UX Designing skills Chennai
# ..    ...  ...                                                ...
# 437  p853  ...  Programming skills and Digital skills Bhubaneswar
# 438  p854  ...    Programming skills and Digital skills New Delhi
# 439  p855  ...                               AML analytics Mumbai
# 440  p856  ...        Programming skills and Digital skills Delhi
# 441  p857  ...                                        Java Nagpur
#
# [442 rows x 4 columns]

# %%
df1.drop(['location', 'required_skills'], axis = 1, inplace= True)

# %%
a=df1.values.tolist()

# %%
for i in a:
    print(i,"\n")
# Out:
# ['p3', 'Anroid, iOS Development Kolkata']
#
# ['p4', 'Java,Python,Groovy Kolkata']
#
# ['p5', 'Python,Groovy,Java Kolkata']
#
# ['p6', 'Python,Groovy,Java Kolkata']
#
# ['p7', 'UI/UX Designing skills Chennai']
#
# ['p9', 'ReactJS,MongoDB exposure to Machine Learning concepts and algorithms,Java,Python Chennai']
#
# ['p10', 'Android,Java,MongoDB exposure to Machine Learning concepts and algorithms Chennai']
#
# ['p11', 'Java/Python,ReactJS,MongoDB,exposure to Machine Learning concepts and algorithms Chennai']
#
# ['p12', 'Android/iOS,Java,MongoDB,exposure to Machine Learning concepts and algorithms Chennai']
#
# ['p13', ' Java/Python,ReactJS,MongoDB Chennai']
#
# ['p15', 'Python,Spark,WEKA,R Bangalore']
#
# ['p20', 'Big data tools,Python,IOT technologies,Structured and Unstructured database, Data modelling Bangalore']
#
# ['p21', 'Python Bangalore']
#
# ['p23', 'Associate expected to have knowledge of allocation and assignment problem Pune']
#
# ...

# %%
# creating function to predict new words
def fun(txt):
    seed_text = txt
    next_words = 1
    
    for _ in range(next_words):
        token_list = tokenizer.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences([token_list], maxlen=max_sequence_len-1, padding='pre')
        predicted = model.predict_classes(token_list, verbose=0)
        output_word = ""
        for word, index in tokenizer.word_index.items():
            if index == predicted:
                output_word = word
                break
        seed_text += " " + output_word
    #return(seed_text)
    return(output_word)

# %%
# running funtion on all values
c=[]
for i in range(len(a)):
    b=[]
    print(a[i][1])
    b.append(a[i][0])
    b.append(fun(a[i][1]))
    c.append(b)
# Out:
# Anroid, iOS Development Kolkata
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# Java,Python,Groovy Kolkata
# Python,Groovy,Java Kolkata
# Python,Groovy,Java Kolkata
# UI/UX Designing skills Chennai
# ReactJS,MongoDB exposure to Machine Learning concepts and algorithms,Java,Python Chennai
# Android,Java,MongoDB exposure to Machine Learning concepts and algorithms Chennai
# Java/Python,ReactJS,MongoDB,exposure to Machine Learning concepts and algorithms Chennai
# ...

# %%
for i in c:
    print(i)
# Out:
# ['p3', 'c378']
# ['p4', 'c358']
# ['p5', 'c61']
# ['p6', 'c61']
# ['p7', 'c182']
# ['p9', 'c3']
# ['p10', 'c115']
# ['p11', 'c571']
# ['p12', 'c115']
# ['p13', 'c553']
# ['p15', 'c770']
# ['p20', 'analytics']
# ['p21', 'c']
# ['p23', 'vision']
# ['p24', 'and']
# ['p25', 'c765']
# ['p26', 'c193']
# ['p27', 'c193']
# ['p28', 'typescript']
# ['p29', 'typescript']
# ['p30', 'c86']
# ['p32', 'hadoop']
# ['p33', 'hadoop']
# ['p34', 'hadoop']
# ['p35', 'c193']
# ['p36', 'c193']
# ['p37', 'c193']
# ['p38', 'lucknow']
# ['p39', 'c772']
# ['p47', 'c250']
# ['p49', 'c450']
# ['p51', 'game']
# ['p52', 'c149']
# ['p63', 'c519']
# ['p64', 'c434']
# ['p65', 'big']
# ['p67', 'c364']
# ['p70', 'c217']
# ['p73', 'c612']
# ['p74', 'c612']
# ['p76', 'c777']
# ['p77', 'c139']
# ['p78', 'c139']
# ['p79', 'c139']
# ['p81', 'c612']
# ['p83', 'c304']
# ['p85', 'c28']
# ['p86', 'iot']
# ['p88', 'c86']
# ['p89', 'c86']
# ['p90', 'c86']
# ['p91', 'image']
# ['p92', 'c86']
# ['p93', 'c86']
# ...

# %%
# storing c54, c356, c288, c246 where corrupted values are present
for i in range(len(c)):
  print(c[i][1])
  if c[i][1][0]!='c' and c[i][1][-1].isnumeric()==0:
    print("test------------------------------",c[i][1])
    c[i][1]='c54, c356, c288, c246'
# Out:
# c378
# c358
# c61
# c61
# c182
# c3
# c115
# c571
# c115
# c553
# c770
# analytics
# test------------------------------ analytics
# c
# vision
# test------------------------------ vision
# and
# test------------------------------ and
# c765
# c193
# c193
# typescript
# test------------------------------ typescript
# typescript
# test------------------------------ typescript
# c86
# hadoop
# test------------------------------ hadoop
# hadoop
# test------------------------------ hadoop
# hadoop
# test------------------------------ hadoop
# c193
# c193
# c193
# lucknow
# test------------------------------ lucknow
# c772
# c250
# c450
# game
# test------------------------------ game
# c149
# c519
# c434
# big
# test------------------------------ big
# c364
# c217
# c612
# c612
# c777
# c139
# c139
# c139
# c612
# c304
# c28
# iot
# test------------------------------ iot
# c86
# c86
# c86
# image
# test------------------------------ image
# c86
# c86
# algorithm
# ...

# %%
for i in c:
    print(i)
# Out:
# ['p3', 'c378']
# ['p4', 'c358']
# ['p5', 'c61']
# ['p6', 'c61']
# ['p7', 'c182']
# ['p9', 'c3']
# ['p10', 'c115']
# ['p11', 'c571']
# ['p12', 'c115']
# ['p13', 'c553']
# ['p15', 'c770']
# ['p20', 'c54, c356, c288, c246']
# ['p21', 'c']
# ['p23', 'c54, c356, c288, c246']
# ['p24', 'c54, c356, c288, c246']
# ['p25', 'c765']
# ['p26', 'c193']
# ['p27', 'c193']
# ['p28', 'c54, c356, c288, c246']
# ['p29', 'c54, c356, c288, c246']
# ['p30', 'c86']
# ['p32', 'c54, c356, c288, c246']
# ['p33', 'c54, c356, c288, c246']
# ['p34', 'c54, c356, c288, c246']
# ['p35', 'c193']
# ['p36', 'c193']
# ['p37', 'c193']
# ['p38', 'c54, c356, c288, c246']
# ['p39', 'c772']
# ['p47', 'c250']
# ['p49', 'c450']
# ['p51', 'c54, c356, c288, c246']
# ['p52', 'c149']
# ['p63', 'c519']
# ['p64', 'c434']
# ['p65', 'c54, c356, c288, c246']
# ['p67', 'c364']
# ['p70', 'c217']
# ['p73', 'c612']
# ['p74', 'c612']
# ['p76', 'c777']
# ['p77', 'c139']
# ['p78', 'c139']
# ['p79', 'c139']
# ['p81', 'c612']
# ...

# %%
df = pd.DataFrame(c, columns =['internship_id', 'login'])

# %%
df
# Out:
#     internship_id                  login
# 0              p3                   c378
# 1              p4                   c358
# 2              p5                    c61
# 3              p6                    c61
# 4              p7                   c182
# ..            ...                    ...
# 437          p853  c54, c356, c288, c246
# 438          p854                   c367
# 439          p855                      c
# 440          p856                   c367
# 441          p857  c54, c356, c288, c246
#
# [442 rows x 2 columns]

# %%
# putting csv file into pandas dataframe
df1 = pd.read_csv("/content/tcs_submission.csv")

# to read starting 5 rows of dataset
df1.head()
# Out:
#   Submission
# 0         p10
# 1        p100
# 2        p107
# 3        p115
# 4        p121

# %%
df1 = df1.rename(columns={'Submission ': 'internship_id'})

# %%
# performing left join on df1 and df2
df2=pd.merge(df1,df,on='internship_id',how='left')

# %%
df2
# Out:
#     internship_id                  login
# 0             p10                   c115
# 1            p100                   c159
# 2            p107                   c391
# 3            p115                   c612
# 4            p121                   c579
# ..            ...                    ...
# 130           p90                    c86
# 131           p92                    c86
# 132           p93                    c86
# 133           p94  c54, c356, c288, c246
# 134           p99                   c458
#
# [135 rows x 2 columns]

# %%
# writing data to csv file
df2.to_csv('/content/file7.csv')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# embedding (Embedding)        (None, 47, 100)           131900
# _________________________________________________________________
# bidirectional (Bidirectional (None, 300)               301200
# _________________________________________________________________
# dense (Dense)                (None, 1319)              397019
# ...
# Total params: 830,119
# Trainable params: 830,119
# Non-trainable params: 0
# _________________________________________________________________
